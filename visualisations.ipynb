# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heart.csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
plt.scatter(x=df.age, y=df.thalach)
plt.xlabel("Age")
plt.ylabel("Thalach")
plt.title("Age Vs Thalach")
plt.show()

# %%
plt.scatter(x=df.age, y=df.chol)
plt.xlabel("Age")
plt.ylabel("Cholestrol")
plt.title("Age Vs Cholestrol")
plt.show()

# %%
plt.scatter(x=df.age, y=df.chol, c="red", marker='*')
plt.scatter(x=df.age, y=df.trestbps, c="blue", marker='x')
plt.scatter(x=df.age, y=df.thalach, c="green", marker='+')
plt.legend(['Chol','Trst-bps','Thalach'])
plt.show()

# %% [markdown]
# # Histograms

# %%
plt.hist(df.age)
plt.xticks(label=df.age, rotation =90)
plt.show()

# %%
df.age.mode()
# Out:
# 0    58
# Name: age, dtype: int64

# %%
df.age.shape
# Out:
# (1025,)

# %%
import seaborn as sns 
sns.heatmap(df[0:10])
# Out:
# <Axes: >

# %%
plt.boxplot(df)
plt.show()

# %%
plt.violinplot(df)
plt.show()

# %%
count_df=df.copy()
count_df.sex = count_df.sex.apply(lambda x:"Male" if x==1 else "Female")
sns.histplot(x=count_df.sex)
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sns.countplot(x=df.age, hue=count_df.sex)
plt.xticks(label=df.age, rotation=90)
plt.show()

# %%
dict ={ "Calories": ["512 cal", "312 cal", "514 cal"]}
df = pd.DataFrame(dict)

# %%
df = df.Calories.apply(lambda row: int(''.join(char for char in row if char not in ['c', 'a', 'l'])))

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#    Calories
# 0       512
# 1       312
# 2       514
